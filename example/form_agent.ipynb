# %%
# !pip install converso==0.0.1
# Out:
# Requirement already satisfied: converso==0.0.1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (0.0.1)
# Requirement already satisfied: langchain<0.2.0,>=0.1.11 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from converso==0.0.1) (0.1.20)
# Requirement already satisfied: langchain-openai<0.0.4,>=0.0.3 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from converso==0.0.1) (0.0.3)
# Requirement already satisfied: langgraph<0.0.16,>=0.0.15 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from converso==0.0.1) (0.0.15)
# Requirement already satisfied: openai==1.6.1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from converso==0.0.1) (1.6.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (2.8.2)
# Requirement already satisfied: sniffio in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from openai==1.6.1->converso==0.0.1) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (0.6.7)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (0.1.85)
# Requirement already satisfied: numpy<2,>=1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.11->converso==0.0.1) (8.5.0)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain-openai<0.0.4,>=0.0.3->converso==0.0.1) (0.5.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.11->converso==0.0.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.11->converso==0.0.1) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.11->converso==0.0.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.11->converso==0.0.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.11->converso==0.0.1) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai==1.6.1->converso==0.0.1) (3.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.11->converso==0.0.1) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.11->converso==0.0.1) (0.9.0)
# Requirement already satisfied: certifi in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.6.1->converso==0.0.1) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.6.1->converso==0.0.1) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.6.1->converso==0.0.1) (0.14.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain<0.2.0,>=0.1.11->converso==0.0.1) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.52->langchain<0.2.0,>=0.1.11->converso==0.0.1) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.11->converso==0.0.1) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.6.1->converso==0.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.6.1->converso==0.0.1) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.11->converso==0.0.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from requests<3,>=2->langchain<0.2.0,>=0.1.11->converso==0.0.1) (2.2.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from tiktoken<0.6.0,>=0.5.2->langchain-openai<0.0.4,>=0.0.3->converso==0.0.1) (2024.5.15)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain<0.2.0,>=0.1.11->converso==0.0.1) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.11->converso==0.0.1) (1.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Define a form tool to the the framework
#
# We define an example tool to showcase the FormTool class. It is somewhat overly complex to show all the validation related flows.

# %%
from typing import Literal, Optional, Type, Any

from pydantic import BaseModel, Field, field_validator, model_validator

from converso import FormTool

class OnlinePurchasePayload(BaseModel):

    allowed_provinces_: list = []

    item: Literal["watch", "shoes", "phone", "book"] = Field(
        description="Item to purchase"
    )

    ebook: Optional[bool] = Field(
        description="If true, the book will be sent as an ebook, if false it will be sent as a physical copy. Required if item is book"
    )

    email: Optional[str] = Field(
        description="Email to send the ebook"
    )

    quantity: int = Field(
        description="Quantity of items to purchase, between 1 and 10"
    )

    region: str = Field(
        description="Region to ship the item"
    )

    province: Optional[str] = Field(
        description="Province to ship the item"
    )

    address: str = Field(
        description="Address to ship the item"
    )

    @field_validator("quantity")
    def validate_quantity(cls, v):
        if v is not None:
            if v < 1 or v > 10:
                raise ValueError("Quantity must be between 1 and 10")
        return v
    
    @field_validator("region")
    def validate_region(cls, v):
        if v is not None:
            if v not in ["puglia", "sicilia", "toscana"]:
                raise ValueError("Region must be one of puglia, sicilia, toscana")
        return v
    
    @model_validator(mode="before")
    def set_allowed_provinces(cls, values: Any) -> Any:
        region = values.get("region").lower() if values.get("region") else None
        province = values.get("province").lower() if values.get("province") else None
        
        if region:
            allowed_provinces = []
            if region == "puglia":
                allowed_provinces = ["bari", "bat", "brindisi", "foggia", "lecce", "taranto"]
            if region == "sicilia":
                allowed_provinces = ["agrigento", "caltanissetta", "catania", "enna", "messina", "palermo", "ragusa", "siracusa", "trapani"]
            if region == "toscana":
                allowed_provinces = ["arezzo", "firenze", "grosseto", "livorno", "lucca", "massa-carrara", "pisa", "pistoia", "prato", "siena"]
            values.update({
                "region": region,
                "province": province,
                "allowed_provinces_": allowed_provinces
            })
        return values

    @model_validator(mode="before")
    def validate_ebook(cls, values: Any) -> Any:
        if values.get("item") == "book" and values.get("ebook") is None:
            raise ValueError("Ebook must be set for books")
        return values
    
    @model_validator(mode="after")
    def validate_province(cls, model: "OnlinePurchasePayload"):
        if model.region and model.province:
            if model.province not in model.allowed_provinces_:
                raise ValueError(f"Province must be one of {model.allowed_provinces_}")
        return model


class OnlinePurchase(FormTool):
    name = "OnlinePurchase"
    description = """Purchase an item from an online store"""
    args_schema: Type[BaseModel] = OnlinePurchasePayload


    def _run_when_complete(
        self,
        *args,
        **kwargs
    ) -> str:
        return "OK"
    
    def get_next_field_to_collect(
        self,
        **kwargs
    ) -> str:
        """
        The default implementation returns the first field that is not set.
        """
        if not self.form.item:
            return "item"
        
        if self.form.item == "book":
            if self.form.ebook == None:
                return "ebook"
            if self.form.ebook == True:
                if not self.form.email:
                    return "email"
                else:
                    return None
            
        if not self.form.quantity:
            return "quantity"
        
        if not self.form.region:
            return "region"
        
        if not self.form.province:
            return "province"
        
        if not self.form.address:
            return "address"
        
        return None

# %%
import os

from langchain.schema import AIMessage, HumanMessage, SystemMessage

from converso import FormAgentExecutor



os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGCHAIN_API_KEY"] = ""
os.environ["LANGCHAIN_PROJECT"] = "example-project"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_TRACING_V2"] = "true"

graph = FormAgentExecutor(
    tools=[
        OnlinePurchase()
    ]
)

history = []
active_form_tool = None

while True:
    human_input = input("Human: ")
    if not human_input:
        break

    inputs = {
        "input": human_input,
        "chat_history": history,
        "intermediate_steps": [],
        "active_form_tool": active_form_tool
    }

    for output in graph.app.stream(inputs, config={"recursion_limit": 25}):
        for key, value in output.items():
            pass

    active_form_tool = value.get("active_form_tool")

    print(output)
    output = graph.parse_output(output)
    print(f"Human: {human_input}")
    print(f"AI: {output}")

    history = [
        *history,
        HumanMessage(content=human_input),
        AIMessage(content=output)
    ]
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/9h/6j5x9wqd07b34wx2mf8gvblm0000gn/T/ipykernel_92353/189722873.py", line 36, in <module>
#     for output in graph.app.stream(inputs, config={"recursion_limit": 25}):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py", line 567, in transform
#     for chunk in self._transform_stream_with_config(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1862, in _transform_stream_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2487, in invoke
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2499, in invoke
#     input = step.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 3963, in invoke
#     return self._call_with_config(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1612, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2499, in invoke
#     input = step.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/passthrough.py", line 217, in invoke
#     return self._call_with_config(identity, input, config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1612, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2487, in invoke
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2499, in invoke
#     input = step.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 3963, in invoke
#     return self._call_with_config(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1612, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2499, in invoke
#     input = step.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/passthrough.py", line 217, in invoke
#     return self._call_with_config(identity, input, config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1612, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2487, in invoke
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2499, in invoke
#     input = step.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 3963, in invoke
#     return self._call_with_config(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1612, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1998, in _configure
#     handler = LangChainTracer(
#               ^^^^^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 91, in __init__
#     self.client = client or get_client()
#                             ^^^^^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/tracers/langchain.py", line 54, in get_client
#     _CLIENT = Client()
#               ^^^^^^^^
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 561, in __init__
#     _validate_api_key_if_hosted(self.api_url, self.api_key)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langsmith/client.py", line 327, in _validate_api_key_if_hosted
#     raise ls_utils.LangSmithUserError(
# langsmith.utils.LangSmithUserError: API key must be provided when using hosted LangSmith API
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 4525, in invoke
#     return self.bound.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 2499, in invoke
#     input = step.invoke(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 3963, in invoke
#     return self._call_with_config(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py", line 1612, in _call_with_config
#     callback_manager = get_callback_manager_for_config(config)
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py", line 402, in get_callback_manager_for_config
#     return CallbackManager.configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 1450, in configure
#     return _configure(
#   File "/Users/gianfrancodemarco/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/callbacks/manager.py", line 2004, in _configure
#     logger.warning(
# Message: 'Unable to load requested LangChainTracer. To disable this warning, unset the LANGCHAIN_TRACING_V2 environment variables.'
# Arguments: ("LangSmithUserError('API key must be provided when using hosted LangSmith API')",)
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 36
#      27     break
#      29 inputs = {
#      30     "input": human_input,
#      31     "chat_history": history,
#      32     "intermediate_steps": [],
#      33     "active_form_tool": active_form_tool
#      34 }
# ---> 36 for output in graph.app.stream(inputs, config={"recursion_limit": 25}):
#      37     for key, value in output.items():
#      38         pass
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:567, in Pregel.transform(self, input, config, output_keys, input_keys, **kwargs)
#     558 def transform(
#     559     self,
#     560     input: Iterator[Union[dict[str, Any], Any]],
#    (...)
#     565     **kwargs: Any,
#     566 ) -> Iterator[Union[dict[str, Any], Any]]:
# --> 567     for chunk in self._transform_stream_with_config(
#     568         input,
#     569         self._transform,
#     570         config,
#     571         output_keys=output_keys,
#     572         input_keys=input_keys,
#     573         **kwargs,
#     574     ):
#     575         yield chunk
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1881, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1879 try:
#    1880     while True:
# -> 1881         chunk: Output = context.run(next, iterator)  # type: ignore
#    1882         yield chunk
#    1883         if final_output_supported:
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:342, in Pregel._transform(self, input, run_manager, config, input_keys, output_keys)
#     332 done, inflight = concurrent.futures.wait(
#     333     [
#     334         executor.submit(proc.invoke, input, config)
#    (...)
#     338     timeout=self.step_timeout,
#     339 )
#     341 # interrupt on failure or timeout
# --> 342 _interrupt_or_proceed(done, inflight, step)
#     344 # apply writes to channels
#     345 _apply_writes(checkpoint, channels, pending_writes, config, step + 1)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:650, in _interrupt_or_proceed(done, inflight, step)
#     648             inflight.pop().cancel()
#     649         # raise the exception
# --> 650         raise exc
#     651         # TODO this is where retry of an entire step would happen
#     653 if inflight:
#     654     # if we got here means we timed out
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:4525, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4519 def invoke(
#    4520     self,
#    4521     input: Input,
#    4522     config: Optional[RunnableConfig] = None,
#    4523     **kwargs: Optional[Any],
#    4524 ) -> Output:
# -> 4525     return self.bound.invoke(
#    4526         input,
#    4527         self._merge_configs(config),
#    4528         **{**self.kwargs, **kwargs},
#    4529     )
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2499, in RunnableSequence.invoke(self, input, config)
#    2497 try:
#    2498     for i, step in enumerate(self.steps):
# -> 2499         input = step.invoke(
#    2500             input,
#    2501             # mark each step as a child run
#    2502             patch_config(
#    2503                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2504             ),
#    2505         )
#    2506 # finish the root run
#    2507 except BaseException as e:
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3963, in RunnableLambda.invoke(self, input, config, **kwargs)
#    3961 """Invoke this runnable synchronously."""
#    3962 if hasattr(self, "func"):
# -> 3963     return self._call_with_config(
#    3964         self._invoke,
#    3965         input,
#    3966         self._config(config, self.func),
#    3967         **kwargs,
#    3968     )
#    3969 else:
#    3970     raise TypeError(
#    3971         "Cannot invoke a coroutine function synchronously."
#    3972         "Use `ainvoke` instead."
#    3973     )
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:1626, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1622     context = copy_context()
#    1623     context.run(var_child_runnable_config.set, child_config)
#    1624     output = cast(
#    1625         Output,
# -> 1626         context.run(
#    1627             call_func_with_variable_args,  # type: ignore[arg-type]
#    1628             func,  # type: ignore[arg-type]
#    1629             input,  # type: ignore[arg-type]
#    1630             config,
#    1631             run_manager,
#    1632             **kwargs,
#    1633         ),
#    1634     )
#    1635 except BaseException as e:
#    1636     run_manager.on_chain_error(e)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     345 if run_manager is not None and accepts_run_manager(func):
#     346     kwargs["run_manager"] = run_manager
# --> 347 return func(input, **kwargs)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3837, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    3835                 output = chunk
#    3836 else:
# -> 3837     output = call_func_with_variable_args(
#    3838         self.func, input, config, run_manager, **kwargs
#    3839     )
#    3840 # If the output is a runnable, invoke it
#    3841 if isinstance(output, Runnable):
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/langchain_core/runnables/config.py:347, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     345 if run_manager is not None and accepts_run_manager(func):
#     346     kwargs["run_manager"] = run_manager
# --> 347 return func(input, **kwargs)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/converso/conversational_engine/form_agent/form_agent_executor.py:110, in FormAgentExecutor.call_agent(self, state)
#     105 if len(state.get("intermediate_steps")
#     106        ) > self.MAX_INTERMEDIATE_STEPS:
#     107     state["intermediate_steps"] = state.get(
#     108         "intermediate_steps")[-self.MAX_INTERMEDIATE_STEPS:]
# --> 110 agent_outcome = self.build_model(state=state).invoke(state)
#     112 updates = {
#     113     "agent_outcome": agent_outcome,
#     114     "tool_choice": None,  # Reset the function call
#     115     "tool_outcome": None,  # Reset the tool outcome
#     116     "error": None  # Reset the error
#     117 }
#     118 return updates
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/converso/conversational_engine/form_agent/form_agent_executor.py:96, in FormAgentExecutor.build_model(self, state)
#      95 def build_model(self, state: AgentState):
# ---> 96     return ModelFactory.build_model(
#      97         state=state,
#      98         tools=self.get_tools(state)
#      99     )
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/converso/conversational_engine/form_agent/model_factory.py:105, in ModelFactory.build_model(state, tools)
#     102 elif state.get("active_form_tool"):
#     103     builder = ModelFactory.build_form_model
# --> 105 return builder(state, tools)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/converso/conversational_engine/form_agent/model_factory.py:129, in ModelFactory.build_default_model(state, tools)
#     125 def build_default_model(
#     126     state: AgentState,
#     127     tools: List[BaseTool] = []
#     128 ):
# --> 129     return ModelFactory.__build_model_from_state_and_prompt(
#     130         state=state,
#     131         prompt=DEFAULT_PROMPT_TEMPLATE,
#     132         tools=tools
#     133     )
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/converso/conversational_engine/form_agent/model_factory.py:177, in ModelFactory.__build_model_from_state_and_prompt(state, prompt, tools)
#     171 def __build_model_from_state_and_prompt(
#     172     state: AgentState,
#     173     prompt: ChatPromptTemplate,
#     174     tools: List[BaseTool] = []
#     175 ):
#     176     return create_openai_tools_agent(
# --> 177         ModelFactory.build_llm(state.get("tool_choice")),
#     178         tools,
#     179         prompt=prompt
#     180     )
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/converso/conversational_engine/form_agent/model_factory.py:123, in ModelFactory.build_llm(tool_choice)
#     115 if tool_choice:
#     116     params["tool_choice"] = {
#     117         "type": "function",
#     118         "function": {
#     119             "name": tool_choice
#     120         }
#     121     }
# --> 123 return ChatOpenAI(**params)
#
# File ~/Desktop/Workspace/converso/venv/lib/python3.12/site-packages/pydantic/v1/main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for ChatOpenAI
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass `openai_api_key` as a named parameter. (type=value_error)
